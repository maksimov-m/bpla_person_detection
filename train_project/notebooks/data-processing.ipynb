# %% [markdown]
# # В этом ноутбуке происходит предобработка разметки к формату для PyTorch (x_min, y_min, x_max, y_max)

# %%
import os

def convert_polygon_to_pytorch(txt_dir, output_dir):
    """
    Converts YOLO-style polygon bounding boxes (x1, y1, x2, y2, ..., xN, yN) 
    into PyTorch format (x_min, y_min, x_max, y_max) via an intermediate YOLO conversion step.

    :param txt_dir: Directory containing original YOLO polygon txt files
    :param output_dir: Directory where converted txt files will be saved
    """
    if not os.path.exists(output_dir):
        os.makedirs(output_dir)

    txt_files = [f for f in os.listdir(txt_dir) if f.endswith(".txt")]

    for file_name in txt_files:
        input_path = os.path.join(txt_dir, file_name)
        output_path = os.path.join(output_dir, file_name)

        with open(input_path, "r") as f:
            lines = f.readlines()

        converted_lines = []
        for line in lines:
            values = line.strip().split()
            
            cls_id = int(values[0])
            coords = list(map(float, values[1:]))  # Extract coordinates dynamically

            # Step 1: Take YOLO format (x_center, y_center, width, height)
            x_center = coords[0]
            y_center = coords[1]
            width = coords[2]
            height = coords[3]

            # Step 2: Calculate (x1, y1, x2, y2) from (x_center, y_center, width, height)
            final_x1 = x_center - (width / 2)
            final_y1 = y_center - (height / 2)
            final_x2 = x_center + (width / 2)
            final_y2 = y_center + (height / 2)

            # Save final PyTorch format
            converted_lines.append(f"{cls_id} {final_x1:.6f} {final_y1:.6f} {final_x2:.6f} {final_y2:.6f}\n")

        # Save new label file in PyTorch format
        with open(output_path, "w") as f:
            f.writelines(converted_lines)

        print(f"Converted {file_name} → {output_path}")

# Example Usage
convert_polygon_to_pytorch("../data/test/labels", "../data/test/labels_converted")
convert_polygon_to_pytorch("../data/train/labels", "../data/train/labels_converted")
convert_polygon_to_pytorch("../data/val/labels", "../data/val/labels_converted")
# Out:
# Converted 1005.txt → ../data/test/labels_converted\1005.txt
# Converted 1029.txt → ../data/test/labels_converted\1029.txt
# Converted 1045.txt → ../data/test/labels_converted\1045.txt
# Converted 1053.txt → ../data/test/labels_converted\1053.txt
# Converted 1063.txt → ../data/test/labels_converted\1063.txt
# Converted 1065.txt → ../data/test/labels_converted\1065.txt
# Converted 1069.txt → ../data/test/labels_converted\1069.txt
# Converted 1114.txt → ../data/test/labels_converted\1114.txt
# Converted 1118.txt → ../data/test/labels_converted\1118.txt
# Converted 1121.txt → ../data/test/labels_converted\1121.txt
# Converted 1131.txt → ../data/test/labels_converted\1131.txt
# Converted 1154.txt → ../data/test/labels_converted\1154.txt
# Converted 1166.txt → ../data/test/labels_converted\1166.txt
# Converted 1187.txt → ../data/test/labels_converted\1187.txt
# Converted 1190.txt → ../data/test/labels_converted\1190.txt
# Converted 1193.txt → ../data/test/labels_converted\1193.txt
# Converted 1197.txt → ../data/test/labels_converted\1197.txt
# Converted 1208.txt → ../data/test/labels_converted\1208.txt
# Converted 1211.txt → ../data/test/labels_converted\1211.txt
# Converted 1214.txt → ../data/test/labels_converted\1214.txt
# Converted 1225.txt → ../data/test/labels_converted\1225.txt
# Converted 1235.txt → ../data/test/labels_converted\1235.txt
# Converted 1242.txt → ../data/test/labels_converted\1242.txt
# Converted 1271.txt → ../data/test/labels_converted\1271.txt
# Converted 1272.txt → ../data/test/labels_converted\1272.txt
# Converted 1275.txt → ../data/test/labels_converted\1275.txt
# Converted 1282.txt → ../data/test/labels_converted\1282.txt
# Converted 1288.txt → ../data/test/labels_converted\1288.txt
# Converted 1291.txt → ../data/test/labels_converted\1291.txt
# Converted 1308.txt → ../data/test/labels_converted\1308.txt
# Converted 1311.txt → ../data/test/labels_converted\1311.txt
# Converted 1316.txt → ../data/test/labels_converted\1316.txt
# Converted 1319.txt → ../data/test/labels_converted\1319.txt
# Converted 1321.txt → ../data/test/labels_converted\1321.txt
# Converted 1325.txt → ../data/test/labels_converted\1325.txt
# Converted 1331.txt → ../data/test/labels_converted\1331.txt
# Converted 1349.txt → ../data/test/labels_converted\1349.txt
# Converted 1359.txt → ../data/test/labels_converted\1359.txt
# Converted 412.txt → ../data/test/labels_converted\412.txt
# Converted 413.txt → ../data/test/labels_converted\413.txt
# Converted 428.txt → ../data/test/labels_converted\428.txt
# Converted 438.txt → ../data/test/labels_converted\438.txt
# Converted 443.txt → ../data/test/labels_converted\443.txt
# Converted 458.txt → ../data/test/labels_converted\458.txt
# Converted 466.txt → ../data/test/labels_converted\466.txt
# Converted 471.txt → ../data/test/labels_converted\471.txt
# Converted 475.txt → ../data/test/labels_converted\475.txt
# Converted 494.txt → ../data/test/labels_converted\494.txt
# Converted 501.txt → ../data/test/labels_converted\501.txt
# Converted 527.txt → ../data/test/labels_converted\527.txt
# Converted 529.txt → ../data/test/labels_converted\529.txt
# Converted 531.txt → ../data/test/labels_converted\531.txt
# Converted 585.txt → ../data/test/labels_converted\585.txt
# Converted 601.txt → ../data/test/labels_converted\601.txt
# Converted 610.txt → ../data/test/labels_converted\610.txt
# Converted 614.txt → ../data/test/labels_converted\614.txt
# Converted 618.txt → ../data/test/labels_converted\618.txt
# Converted 623.txt → ../data/test/labels_converted\623.txt
# Converted 626.txt → ../data/test/labels_converted\626.txt
# Converted 643.txt → ../data/test/labels_converted\643.txt
# Converted 656.txt → ../data/test/labels_converted\656.txt
# Converted 659.txt → ../data/test/labels_converted\659.txt
# Converted 669.txt → ../data/test/labels_converted\669.txt
# Converted 681.txt → ../data/test/labels_converted\681.txt
# Converted 684.txt → ../data/test/labels_converted\684.txt
# Converted 687.txt → ../data/test/labels_converted\687.txt
# Converted 689.txt → ../data/test/labels_converted\689.txt
# Converted 709.txt → ../data/test/labels_converted\709.txt
# Converted 720.txt → ../data/test/labels_converted\720.txt
# Converted 730.txt → ../data/test/labels_converted\730.txt
# Converted 758.txt → ../data/test/labels_converted\758.txt
# Converted 771.txt → ../data/test/labels_converted\771.txt
# Converted 774.txt → ../data/test/labels_converted\774.txt
# Converted 802.txt → ../data/test/labels_converted\802.txt
# Converted 807.txt → ../data/test/labels_converted\807.txt
# Converted 811.txt → ../data/test/labels_converted\811.txt
# Converted 840.txt → ../data/test/labels_converted\840.txt
# Converted 842.txt → ../data/test/labels_converted\842.txt
# Converted 843.txt → ../data/test/labels_converted\843.txt
# Converted 852.txt → ../data/test/labels_converted\852.txt
# Converted 870.txt → ../data/test/labels_converted\870.txt
# Converted 874.txt → ../data/test/labels_converted\874.txt
# Converted 878.txt → ../data/test/labels_converted\878.txt
# Converted 890.txt → ../data/test/labels_converted\890.txt
# Converted 896.txt → ../data/test/labels_converted\896.txt
# Converted 903.txt → ../data/test/labels_converted\903.txt
# Converted 909.txt → ../data/test/labels_converted\909.txt
# Converted 921.txt → ../data/test/labels_converted\921.txt
# Converted 931.txt → ../data/test/labels_converted\931.txt
# Converted 941.txt → ../data/test/labels_converted\941.txt
# Converted 961.txt → ../data/test/labels_converted\961.txt
# Converted 967.txt → ../data/test/labels_converted\967.txt
# Converted 977.txt → ../data/test/labels_converted\977.txt
# Converted 984.txt → ../data/test/labels_converted\984.txt
# Converted 986.txt → ../data/test/labels_converted\986.txt
# Converted 993.txt → ../data/test/labels_converted\993.txt
# Converted 1000.txt → ../data/train/labels_converted\1000.txt
# Converted 1001.txt → ../data/train/labels_converted\1001.txt
# Converted 1002.txt → ../data/train/labels_converted\1002.txt
# Converted 1003.txt → ../data/train/labels_converted\1003.txt
# Converted 1004.txt → ../data/train/labels_converted\1004.txt
# Converted 1006.txt → ../data/train/labels_converted\1006.txt
# Converted 1007.txt → ../data/train/labels_converted\1007.txt
# Converted 1008.txt → ../data/train/labels_converted\1008.txt
# Converted 1009.txt → ../data/train/labels_converted\1009.txt
# Converted 1011.txt → ../data/train/labels_converted\1011.txt
# Converted 1012.txt → ../data/train/labels_converted\1012.txt
# Converted 1014.txt → ../data/train/labels_converted\1014.txt
# Converted 1015.txt → ../data/train/labels_converted\1015.txt
# Converted 1016.txt → ../data/train/labels_converted\1016.txt
# Converted 1017.txt → ../data/train/labels_converted\1017.txt
# Converted 1020.txt → ../data/train/labels_converted\1020.txt
# Converted 1021.txt → ../data/train/labels_converted\1021.txt
# Converted 1022.txt → ../data/train/labels_converted\1022.txt
# Converted 1023.txt → ../data/train/labels_converted\1023.txt
# Converted 1024.txt → ../data/train/labels_converted\1024.txt
# Converted 1025.txt → ../data/train/labels_converted\1025.txt
# Converted 1027.txt → ../data/train/labels_converted\1027.txt
# Converted 1030.txt → ../data/train/labels_converted\1030.txt
# Converted 1031.txt → ../data/train/labels_converted\1031.txt
# Converted 1032.txt → ../data/train/labels_converted\1032.txt
# Converted 1033.txt → ../data/train/labels_converted\1033.txt
# Converted 1034.txt → ../data/train/labels_converted\1034.txt
# Converted 1035.txt → ../data/train/labels_converted\1035.txt
# Converted 1036.txt → ../data/train/labels_converted\1036.txt
# Converted 1037.txt → ../data/train/labels_converted\1037.txt
# Converted 1038.txt → ../data/train/labels_converted\1038.txt
# Converted 1039.txt → ../data/train/labels_converted\1039.txt
# Converted 1041.txt → ../data/train/labels_converted\1041.txt
# Converted 1042.txt → ../data/train/labels_converted\1042.txt
# Converted 1044.txt → ../data/train/labels_converted\1044.txt
# Converted 1046.txt → ../data/train/labels_converted\1046.txt
# Converted 1047.txt → ../data/train/labels_converted\1047.txt
# Converted 1049.txt → ../data/train/labels_converted\1049.txt
# Converted 1050.txt → ../data/train/labels_converted\1050.txt
# Converted 1052.txt → ../data/train/labels_converted\1052.txt
# Converted 1054.txt → ../data/train/labels_converted\1054.txt
# Converted 1055.txt → ../data/train/labels_converted\1055.txt
# Converted 1056.txt → ../data/train/labels_converted\1056.txt
# Converted 1057.txt → ../data/train/labels_converted\1057.txt
# Converted 1058.txt → ../data/train/labels_converted\1058.txt
# Converted 1059.txt → ../data/train/labels_converted\1059.txt
# Converted 1060.txt → ../data/train/labels_converted\1060.txt
# Converted 1061.txt → ../data/train/labels_converted\1061.txt
# Converted 1064.txt → ../data/train/labels_converted\1064.txt
# Converted 1066.txt → ../data/train/labels_converted\1066.txt
# Converted 1067.txt → ../data/train/labels_converted\1067.txt
# Converted 1068.txt → ../data/train/labels_converted\1068.txt
# Converted 1070.txt → ../data/train/labels_converted\1070.txt
# Converted 1071.txt → ../data/train/labels_converted\1071.txt
# Converted 1073.txt → ../data/train/labels_converted\1073.txt
# Converted 1074.txt → ../data/train/labels_converted\1074.txt
# Converted 1075.txt → ../data/train/labels_converted\1075.txt
# Converted 1077.txt → ../data/train/labels_converted\1077.txt
# Converted 1078.txt → ../data/train/labels_converted\1078.txt
# Converted 1079.txt → ../data/train/labels_converted\1079.txt
# Converted 1080.txt → ../data/train/labels_converted\1080.txt
# Converted 1082.txt → ../data/train/labels_converted\1082.txt
# Converted 1083.txt → ../data/train/labels_converted\1083.txt
# Converted 1084.txt → ../data/train/labels_converted\1084.txt
# Converted 1085.txt → ../data/train/labels_converted\1085.txt
# Converted 1086.txt → ../data/train/labels_converted\1086.txt
# Converted 1088.txt → ../data/train/labels_converted\1088.txt
# Converted 1089.txt → ../data/train/labels_converted\1089.txt
# Converted 1090.txt → ../data/train/labels_converted\1090.txt
# Converted 1091.txt → ../data/train/labels_converted\1091.txt
# Converted 1093.txt → ../data/train/labels_converted\1093.txt
# Converted 1094.txt → ../data/train/labels_converted\1094.txt
# Converted 1095.txt → ../data/train/labels_converted\1095.txt
# Converted 1096.txt → ../data/train/labels_converted\1096.txt
# Converted 1097.txt → ../data/train/labels_converted\1097.txt
# Converted 1098.txt → ../data/train/labels_converted\1098.txt
# Converted 1099.txt → ../data/train/labels_converted\1099.txt
# Converted 1100.txt → ../data/train/labels_converted\1100.txt
# Converted 1103.txt → ../data/train/labels_converted\1103.txt
# Converted 1104.txt → ../data/train/labels_converted\1104.txt
# Converted 1105.txt → ../data/train/labels_converted\1105.txt
# Converted 1107.txt → ../data/train/labels_converted\1107.txt
# Converted 1108.txt → ../data/train/labels_converted\1108.txt
# Converted 1109.txt → ../data/train/labels_converted\1109.txt
# Converted 1110.txt → ../data/train/labels_converted\1110.txt
# Converted 1111.txt → ../data/train/labels_converted\1111.txt
# Converted 1112.txt → ../data/train/labels_converted\1112.txt
# Converted 1113.txt → ../data/train/labels_converted\1113.txt
# Converted 1115.txt → ../data/train/labels_converted\1115.txt
# Converted 1116.txt → ../data/train/labels_converted\1116.txt
# Converted 1117.txt → ../data/train/labels_converted\1117.txt
# Converted 1119.txt → ../data/train/labels_converted\1119.txt
# Converted 1122.txt → ../data/train/labels_converted\1122.txt
# Converted 1123.txt → ../data/train/labels_converted\1123.txt
# Converted 1124.txt → ../data/train/labels_converted\1124.txt
# Converted 1125.txt → ../data/train/labels_converted\1125.txt
# Converted 1126.txt → ../data/train/labels_converted\1126.txt
# Converted 1127.txt → ../data/train/labels_converted\1127.txt
# Converted 1128.txt → ../data/train/labels_converted\1128.txt
# Converted 1129.txt → ../data/train/labels_converted\1129.txt
# Converted 1130.txt → ../data/train/labels_converted\1130.txt
# Converted 1133.txt → ../data/train/labels_converted\1133.txt
# Converted 1135.txt → ../data/train/labels_converted\1135.txt
# Converted 1136.txt → ../data/train/labels_converted\1136.txt
# Converted 1138.txt → ../data/train/labels_converted\1138.txt
# Converted 1139.txt → ../data/train/labels_converted\1139.txt
# Converted 1140.txt → ../data/train/labels_converted\1140.txt
# Converted 1141.txt → ../data/train/labels_converted\1141.txt
# Converted 1142.txt → ../data/train/labels_converted\1142.txt
# Converted 1143.txt → ../data/train/labels_converted\1143.txt
# Converted 1144.txt → ../data/train/labels_converted\1144.txt
# Converted 1145.txt → ../data/train/labels_converted\1145.txt
# Converted 1147.txt → ../data/train/labels_converted\1147.txt
# Converted 1148.txt → ../data/train/labels_converted\1148.txt
# Converted 1149.txt → ../data/train/labels_converted\1149.txt
# Converted 1150.txt → ../data/train/labels_converted\1150.txt
# Converted 1151.txt → ../data/train/labels_converted\1151.txt
# Converted 1152.txt → ../data/train/labels_converted\1152.txt
# Converted 1155.txt → ../data/train/labels_converted\1155.txt
# Converted 1156.txt → ../data/train/labels_converted\1156.txt
# Converted 1157.txt → ../data/train/labels_converted\1157.txt
# Converted 1158.txt → ../data/train/labels_converted\1158.txt
# Converted 1159.txt → ../data/train/labels_converted\1159.txt
# Converted 1160.txt → ../data/train/labels_converted\1160.txt
# Converted 1161.txt → ../data/train/labels_converted\1161.txt
# Converted 1162.txt → ../data/train/labels_converted\1162.txt
# Converted 1163.txt → ../data/train/labels_converted\1163.txt
# Converted 1164.txt → ../data/train/labels_converted\1164.txt
# Converted 1165.txt → ../data/train/labels_converted\1165.txt
# Converted 1167.txt → ../data/train/labels_converted\1167.txt
# Converted 1168.txt → ../data/train/labels_converted\1168.txt
# Converted 1169.txt → ../data/train/labels_converted\1169.txt
# Converted 1171.txt → ../data/train/labels_converted\1171.txt
# Converted 1172.txt → ../data/train/labels_converted\1172.txt
# Converted 1173.txt → ../data/train/labels_converted\1173.txt
# Converted 1174.txt → ../data/train/labels_converted\1174.txt
# Converted 1175.txt → ../data/train/labels_converted\1175.txt
# Converted 1177.txt → ../data/train/labels_converted\1177.txt
# Converted 1178.txt → ../data/train/labels_converted\1178.txt
# Converted 1180.txt → ../data/train/labels_converted\1180.txt
# Converted 1182.txt → ../data/train/labels_converted\1182.txt
# Converted 1183.txt → ../data/train/labels_converted\1183.txt
# Converted 1184.txt → ../data/train/labels_converted\1184.txt
# Converted 1185.txt → ../data/train/labels_converted\1185.txt
# Converted 1186.txt → ../data/train/labels_converted\1186.txt
# Converted 1188.txt → ../data/train/labels_converted\1188.txt
# Converted 1189.txt → ../data/train/labels_converted\1189.txt
# Converted 1191.txt → ../data/train/labels_converted\1191.txt
# Converted 1192.txt → ../data/train/labels_converted\1192.txt
# Converted 1194.txt → ../data/train/labels_converted\1194.txt
# Converted 1195.txt → ../data/train/labels_converted\1195.txt
# Converted 1198.txt → ../data/train/labels_converted\1198.txt
# Converted 1200.txt → ../data/train/labels_converted\1200.txt
# Converted 1201.txt → ../data/train/labels_converted\1201.txt
# Converted 1203.txt → ../data/train/labels_converted\1203.txt
# Converted 1205.txt → ../data/train/labels_converted\1205.txt
# Converted 1206.txt → ../data/train/labels_converted\1206.txt
# Converted 1207.txt → ../data/train/labels_converted\1207.txt
# Converted 1209.txt → ../data/train/labels_converted\1209.txt
# Converted 1210.txt → ../data/train/labels_converted\1210.txt
# Converted 1212.txt → ../data/train/labels_converted\1212.txt
# Converted 1213.txt → ../data/train/labels_converted\1213.txt
# Converted 1215.txt → ../data/train/labels_converted\1215.txt
# Converted 1216.txt → ../data/train/labels_converted\1216.txt
# Converted 1217.txt → ../data/train/labels_converted\1217.txt
# Converted 1218.txt → ../data/train/labels_converted\1218.txt
# Converted 1219.txt → ../data/train/labels_converted\1219.txt
# Converted 1220.txt → ../data/train/labels_converted\1220.txt
# Converted 1221.txt → ../data/train/labels_converted\1221.txt
# Converted 1222.txt → ../data/train/labels_converted\1222.txt
# Converted 1224.txt → ../data/train/labels_converted\1224.txt
# Converted 1226.txt → ../data/train/labels_converted\1226.txt
# Converted 1228.txt → ../data/train/labels_converted\1228.txt
# Converted 1229.txt → ../data/train/labels_converted\1229.txt
# Converted 1230.txt → ../data/train/labels_converted\1230.txt
# Converted 1231.txt → ../data/train/labels_converted\1231.txt
# Converted 1233.txt → ../data/train/labels_converted\1233.txt
# Converted 1236.txt → ../data/train/labels_converted\1236.txt
# Converted 1239.txt → ../data/train/labels_converted\1239.txt
# Converted 1240.txt → ../data/train/labels_converted\1240.txt
# Converted 1241.txt → ../data/train/labels_converted\1241.txt
# Converted 1244.txt → ../data/train/labels_converted\1244.txt
# Converted 1245.txt → ../data/train/labels_converted\1245.txt
# Converted 1246.txt → ../data/train/labels_converted\1246.txt
# Converted 1247.txt → ../data/train/labels_converted\1247.txt
# Converted 1248.txt → ../data/train/labels_converted\1248.txt
# Converted 1249.txt → ../data/train/labels_converted\1249.txt
# Converted 1250.txt → ../data/train/labels_converted\1250.txt
# Converted 1251.txt → ../data/train/labels_converted\1251.txt
# Converted 1253.txt → ../data/train/labels_converted\1253.txt
# Converted 1255.txt → ../data/train/labels_converted\1255.txt
# Converted 1256.txt → ../data/train/labels_converted\1256.txt
# Converted 1257.txt → ../data/train/labels_converted\1257.txt
# Converted 1258.txt → ../data/train/labels_converted\1258.txt
# Converted 1259.txt → ../data/train/labels_converted\1259.txt
# Converted 1260.txt → ../data/train/labels_converted\1260.txt
# Converted 1261.txt → ../data/train/labels_converted\1261.txt
# Converted 1262.txt → ../data/train/labels_converted\1262.txt
# Converted 1263.txt → ../data/train/labels_converted\1263.txt
# Converted 1264.txt → ../data/train/labels_converted\1264.txt
# Converted 1265.txt → ../data/train/labels_converted\1265.txt
# Converted 1266.txt → ../data/train/labels_converted\1266.txt
# Converted 1267.txt → ../data/train/labels_converted\1267.txt
# Converted 1269.txt → ../data/train/labels_converted\1269.txt
# Converted 1273.txt → ../data/train/labels_converted\1273.txt
# Converted 1274.txt → ../data/train/labels_converted\1274.txt
# Converted 1276.txt → ../data/train/labels_converted\1276.txt
# Converted 1277.txt → ../data/train/labels_converted\1277.txt
# Converted 1278.txt → ../data/train/labels_converted\1278.txt
# Converted 1279.txt → ../data/train/labels_converted\1279.txt
# Converted 1280.txt → ../data/train/labels_converted\1280.txt
# Converted 1283.txt → ../data/train/labels_converted\1283.txt
# Converted 1284.txt → ../data/train/labels_converted\1284.txt
# Converted 1285.txt → ../data/train/labels_converted\1285.txt
# Converted 1286.txt → ../data/train/labels_converted\1286.txt
# Converted 1287.txt → ../data/train/labels_converted\1287.txt
# Converted 1289.txt → ../data/train/labels_converted\1289.txt
# Converted 1290.txt → ../data/train/labels_converted\1290.txt
# Converted 1292.txt → ../data/train/labels_converted\1292.txt
# Converted 1295.txt → ../data/train/labels_converted\1295.txt
# Converted 1296.txt → ../data/train/labels_converted\1296.txt
# Converted 1297.txt → ../data/train/labels_converted\1297.txt
# Converted 1298.txt → ../data/train/labels_converted\1298.txt
# Converted 1299.txt → ../data/train/labels_converted\1299.txt
# Converted 1300.txt → ../data/train/labels_converted\1300.txt
# Converted 1301.txt → ../data/train/labels_converted\1301.txt
# Converted 1303.txt → ../data/train/labels_converted\1303.txt
# Converted 1304.txt → ../data/train/labels_converted\1304.txt
# Converted 1306.txt → ../data/train/labels_converted\1306.txt
# Converted 1307.txt → ../data/train/labels_converted\1307.txt
# Converted 1309.txt → ../data/train/labels_converted\1309.txt
# Converted 1310.txt → ../data/train/labels_converted\1310.txt
# Converted 1313.txt → ../data/train/labels_converted\1313.txt
# Converted 1314.txt → ../data/train/labels_converted\1314.txt
# Converted 1315.txt → ../data/train/labels_converted\1315.txt
# Converted 1318.txt → ../data/train/labels_converted\1318.txt
# Converted 1320.txt → ../data/train/labels_converted\1320.txt
# Converted 1322.txt → ../data/train/labels_converted\1322.txt
# Converted 1323.txt → ../data/train/labels_converted\1323.txt
# Converted 1324.txt → ../data/train/labels_converted\1324.txt
# Converted 1327.txt → ../data/train/labels_converted\1327.txt
# Converted 1328.txt → ../data/train/labels_converted\1328.txt
# Converted 1329.txt → ../data/train/labels_converted\1329.txt
# Converted 1330.txt → ../data/train/labels_converted\1330.txt
# Converted 1332.txt → ../data/train/labels_converted\1332.txt
# Converted 1333.txt → ../data/train/labels_converted\1333.txt
# Converted 1334.txt → ../data/train/labels_converted\1334.txt
# Converted 1335.txt → ../data/train/labels_converted\1335.txt
# Converted 1337.txt → ../data/train/labels_converted\1337.txt
# Converted 1338.txt → ../data/train/labels_converted\1338.txt
# Converted 1339.txt → ../data/train/labels_converted\1339.txt
# Converted 1340.txt → ../data/train/labels_converted\1340.txt
# Converted 1341.txt → ../data/train/labels_converted\1341.txt
# Converted 1343.txt → ../data/train/labels_converted\1343.txt
# Converted 1344.txt → ../data/train/labels_converted\1344.txt
# Converted 1345.txt → ../data/train/labels_converted\1345.txt
# Converted 1346.txt → ../data/train/labels_converted\1346.txt
# Converted 1347.txt → ../data/train/labels_converted\1347.txt
# Converted 1348.txt → ../data/train/labels_converted\1348.txt
# Converted 1350.txt → ../data/train/labels_converted\1350.txt
# Converted 1351.txt → ../data/train/labels_converted\1351.txt
# Converted 1352.txt → ../data/train/labels_converted\1352.txt
# Converted 1353.txt → ../data/train/labels_converted\1353.txt
# Converted 1354.txt → ../data/train/labels_converted\1354.txt
# Converted 1357.txt → ../data/train/labels_converted\1357.txt
# Converted 1358.txt → ../data/train/labels_converted\1358.txt
# Converted 1360.txt → ../data/train/labels_converted\1360.txt
# Converted 1361.txt → ../data/train/labels_converted\1361.txt
# Converted 1362.txt → ../data/train/labels_converted\1362.txt
# Converted 1363.txt → ../data/train/labels_converted\1363.txt
# Converted 408.txt → ../data/train/labels_converted\408.txt
# Converted 409.txt → ../data/train/labels_converted\409.txt
# Converted 410.txt → ../data/train/labels_converted\410.txt
# Converted 414.txt → ../data/train/labels_converted\414.txt
# Converted 415.txt → ../data/train/labels_converted\415.txt
# Converted 416.txt → ../data/train/labels_converted\416.txt
# Converted 419.txt → ../data/train/labels_converted\419.txt
# Converted 420.txt → ../data/train/labels_converted\420.txt
# Converted 422.txt → ../data/train/labels_converted\422.txt
# Converted 423.txt → ../data/train/labels_converted\423.txt
# Converted 424.txt → ../data/train/labels_converted\424.txt
# Converted 425.txt → ../data/train/labels_converted\425.txt
# Converted 426.txt → ../data/train/labels_converted\426.txt
# Converted 427.txt → ../data/train/labels_converted\427.txt
# Converted 429.txt → ../data/train/labels_converted\429.txt
# Converted 430.txt → ../data/train/labels_converted\430.txt
# Converted 432.txt → ../data/train/labels_converted\432.txt
# Converted 433.txt → ../data/train/labels_converted\433.txt
# Converted 435.txt → ../data/train/labels_converted\435.txt
# Converted 436.txt → ../data/train/labels_converted\436.txt
# Converted 437.txt → ../data/train/labels_converted\437.txt
# Converted 439.txt → ../data/train/labels_converted\439.txt
# Converted 440.txt → ../data/train/labels_converted\440.txt
# Converted 441.txt → ../data/train/labels_converted\441.txt
# Converted 442.txt → ../data/train/labels_converted\442.txt
# Converted 444.txt → ../data/train/labels_converted\444.txt
# Converted 445.txt → ../data/train/labels_converted\445.txt
# Converted 446.txt → ../data/train/labels_converted\446.txt
# Converted 447.txt → ../data/train/labels_converted\447.txt
# Converted 448.txt → ../data/train/labels_converted\448.txt
# Converted 449.txt → ../data/train/labels_converted\449.txt
# Converted 450.txt → ../data/train/labels_converted\450.txt
# Converted 451.txt → ../data/train/labels_converted\451.txt
# Converted 453.txt → ../data/train/labels_converted\453.txt
# Converted 454.txt → ../data/train/labels_converted\454.txt
# Converted 455.txt → ../data/train/labels_converted\455.txt
# Converted 457.txt → ../data/train/labels_converted\457.txt
# Converted 459.txt → ../data/train/labels_converted\459.txt
# Converted 460.txt → ../data/train/labels_converted\460.txt
# Converted 461.txt → ../data/train/labels_converted\461.txt
# Converted 463.txt → ../data/train/labels_converted\463.txt
# Converted 464.txt → ../data/train/labels_converted\464.txt
# Converted 465.txt → ../data/train/labels_converted\465.txt
# Converted 467.txt → ../data/train/labels_converted\467.txt
# Converted 468.txt → ../data/train/labels_converted\468.txt
# Converted 469.txt → ../data/train/labels_converted\469.txt
# Converted 470.txt → ../data/train/labels_converted\470.txt
# Converted 472.txt → ../data/train/labels_converted\472.txt
# Converted 474.txt → ../data/train/labels_converted\474.txt
# Converted 477.txt → ../data/train/labels_converted\477.txt
# Converted 479.txt → ../data/train/labels_converted\479.txt
# Converted 480.txt → ../data/train/labels_converted\480.txt
# Converted 481.txt → ../data/train/labels_converted\481.txt
# Converted 482.txt → ../data/train/labels_converted\482.txt
# Converted 483.txt → ../data/train/labels_converted\483.txt
# Converted 485.txt → ../data/train/labels_converted\485.txt
# Converted 486.txt → ../data/train/labels_converted\486.txt
# Converted 487.txt → ../data/train/labels_converted\487.txt
# Converted 488.txt → ../data/train/labels_converted\488.txt
# Converted 490.txt → ../data/train/labels_converted\490.txt
# Converted 491.txt → ../data/train/labels_converted\491.txt
# Converted 492.txt → ../data/train/labels_converted\492.txt
# Converted 493.txt → ../data/train/labels_converted\493.txt
# Converted 495.txt → ../data/train/labels_converted\495.txt
# Converted 496.txt → ../data/train/labels_converted\496.txt
# Converted 497.txt → ../data/train/labels_converted\497.txt
# Converted 498.txt → ../data/train/labels_converted\498.txt
# Converted 499.txt → ../data/train/labels_converted\499.txt
# Converted 502.txt → ../data/train/labels_converted\502.txt
# Converted 503.txt → ../data/train/labels_converted\503.txt
# Converted 507.txt → ../data/train/labels_converted\507.txt
# Converted 508.txt → ../data/train/labels_converted\508.txt
# Converted 509.txt → ../data/train/labels_converted\509.txt
# Converted 510.txt → ../data/train/labels_converted\510.txt
# Converted 512.txt → ../data/train/labels_converted\512.txt
# Converted 513.txt → ../data/train/labels_converted\513.txt
# Converted 514.txt → ../data/train/labels_converted\514.txt
# Converted 518.txt → ../data/train/labels_converted\518.txt
# Converted 519.txt → ../data/train/labels_converted\519.txt
# Converted 520.txt → ../data/train/labels_converted\520.txt
# Converted 521.txt → ../data/train/labels_converted\521.txt
# Converted 522.txt → ../data/train/labels_converted\522.txt
# Converted 523.txt → ../data/train/labels_converted\523.txt
# Converted 524.txt → ../data/train/labels_converted\524.txt
# Converted 525.txt → ../data/train/labels_converted\525.txt
# Converted 526.txt → ../data/train/labels_converted\526.txt
# Converted 528.txt → ../data/train/labels_converted\528.txt
# Converted 530.txt → ../data/train/labels_converted\530.txt
# Converted 532.txt → ../data/train/labels_converted\532.txt
# Converted 533.txt → ../data/train/labels_converted\533.txt
# Converted 534.txt → ../data/train/labels_converted\534.txt
# Converted 535.txt → ../data/train/labels_converted\535.txt
# Converted 536.txt → ../data/train/labels_converted\536.txt
# Converted 537.txt → ../data/train/labels_converted\537.txt
# Converted 538.txt → ../data/train/labels_converted\538.txt
# Converted 539.txt → ../data/train/labels_converted\539.txt
# Converted 540.txt → ../data/train/labels_converted\540.txt
# Converted 541.txt → ../data/train/labels_converted\541.txt
# Converted 542.txt → ../data/train/labels_converted\542.txt
# Converted 543.txt → ../data/train/labels_converted\543.txt
# Converted 544.txt → ../data/train/labels_converted\544.txt
# Converted 545.txt → ../data/train/labels_converted\545.txt
# Converted 546.txt → ../data/train/labels_converted\546.txt
# Converted 547.txt → ../data/train/labels_converted\547.txt
# Converted 548.txt → ../data/train/labels_converted\548.txt
# Converted 549.txt → ../data/train/labels_converted\549.txt
# Converted 550.txt → ../data/train/labels_converted\550.txt
# Converted 551.txt → ../data/train/labels_converted\551.txt
# Converted 552.txt → ../data/train/labels_converted\552.txt
# Converted 553.txt → ../data/train/labels_converted\553.txt
# Converted 554.txt → ../data/train/labels_converted\554.txt
# Converted 555.txt → ../data/train/labels_converted\555.txt
# Converted 556.txt → ../data/train/labels_converted\556.txt
# Converted 557.txt → ../data/train/labels_converted\557.txt
# Converted 558.txt → ../data/train/labels_converted\558.txt
# Converted 561.txt → ../data/train/labels_converted\561.txt
# Converted 562.txt → ../data/train/labels_converted\562.txt
# Converted 563.txt → ../data/train/labels_converted\563.txt
# Converted 564.txt → ../data/train/labels_converted\564.txt
# Converted 565.txt → ../data/train/labels_converted\565.txt
# Converted 566.txt → ../data/train/labels_converted\566.txt
# Converted 567.txt → ../data/train/labels_converted\567.txt
# Converted 569.txt → ../data/train/labels_converted\569.txt
# Converted 570.txt → ../data/train/labels_converted\570.txt
# Converted 571.txt → ../data/train/labels_converted\571.txt
# Converted 572.txt → ../data/train/labels_converted\572.txt
# Converted 573.txt → ../data/train/labels_converted\573.txt
# Converted 574.txt → ../data/train/labels_converted\574.txt
# Converted 575.txt → ../data/train/labels_converted\575.txt
# Converted 576.txt → ../data/train/labels_converted\576.txt
# Converted 577.txt → ../data/train/labels_converted\577.txt
# Converted 578.txt → ../data/train/labels_converted\578.txt
# Converted 579.txt → ../data/train/labels_converted\579.txt
# Converted 580.txt → ../data/train/labels_converted\580.txt
# Converted 581.txt → ../data/train/labels_converted\581.txt
# Converted 583.txt → ../data/train/labels_converted\583.txt
# Converted 584.txt → ../data/train/labels_converted\584.txt
# Converted 586.txt → ../data/train/labels_converted\586.txt
# Converted 587.txt → ../data/train/labels_converted\587.txt
# Converted 588.txt → ../data/train/labels_converted\588.txt
# Converted 589.txt → ../data/train/labels_converted\589.txt
# Converted 590.txt → ../data/train/labels_converted\590.txt
# Converted 593.txt → ../data/train/labels_converted\593.txt
# Converted 594.txt → ../data/train/labels_converted\594.txt
# Converted 596.txt → ../data/train/labels_converted\596.txt
# Converted 597.txt → ../data/train/labels_converted\597.txt
# Converted 599.txt → ../data/train/labels_converted\599.txt
# Converted 600.txt → ../data/train/labels_converted\600.txt
# Converted 602.txt → ../data/train/labels_converted\602.txt
# Converted 603.txt → ../data/train/labels_converted\603.txt
# Converted 604.txt → ../data/train/labels_converted\604.txt
# Converted 606.txt → ../data/train/labels_converted\606.txt
# Converted 607.txt → ../data/train/labels_converted\607.txt
# Converted 608.txt → ../data/train/labels_converted\608.txt
# Converted 609.txt → ../data/train/labels_converted\609.txt
# Converted 611.txt → ../data/train/labels_converted\611.txt
# Converted 612.txt → ../data/train/labels_converted\612.txt
# Converted 613.txt → ../data/train/labels_converted\613.txt
# Converted 615.txt → ../data/train/labels_converted\615.txt
# Converted 616.txt → ../data/train/labels_converted\616.txt
# Converted 617.txt → ../data/train/labels_converted\617.txt
# Converted 619.txt → ../data/train/labels_converted\619.txt
# Converted 620.txt → ../data/train/labels_converted\620.txt
# Converted 621.txt → ../data/train/labels_converted\621.txt
# Converted 622.txt → ../data/train/labels_converted\622.txt
# Converted 624.txt → ../data/train/labels_converted\624.txt
# Converted 625.txt → ../data/train/labels_converted\625.txt
# Converted 627.txt → ../data/train/labels_converted\627.txt
# Converted 628.txt → ../data/train/labels_converted\628.txt
# Converted 629.txt → ../data/train/labels_converted\629.txt
# Converted 631.txt → ../data/train/labels_converted\631.txt
# Converted 632.txt → ../data/train/labels_converted\632.txt
# Converted 633.txt → ../data/train/labels_converted\633.txt
# Converted 634.txt → ../data/train/labels_converted\634.txt
# Converted 635.txt → ../data/train/labels_converted\635.txt
# Converted 636.txt → ../data/train/labels_converted\636.txt
# Converted 637.txt → ../data/train/labels_converted\637.txt
# Converted 639.txt → ../data/train/labels_converted\639.txt
# Converted 640.txt → ../data/train/labels_converted\640.txt
# Converted 642.txt → ../data/train/labels_converted\642.txt
# Converted 644.txt → ../data/train/labels_converted\644.txt
# Converted 645.txt → ../data/train/labels_converted\645.txt
# Converted 646.txt → ../data/train/labels_converted\646.txt
# Converted 647.txt → ../data/train/labels_converted\647.txt
# Converted 648.txt → ../data/train/labels_converted\648.txt
# Converted 649.txt → ../data/train/labels_converted\649.txt
# Converted 650.txt → ../data/train/labels_converted\650.txt
# Converted 651.txt → ../data/train/labels_converted\651.txt
# Converted 653.txt → ../data/train/labels_converted\653.txt
# Converted 654.txt → ../data/train/labels_converted\654.txt
# Converted 655.txt → ../data/train/labels_converted\655.txt
# Converted 657.txt → ../data/train/labels_converted\657.txt
# Converted 658.txt → ../data/train/labels_converted\658.txt
# Converted 660.txt → ../data/train/labels_converted\660.txt
# Converted 661.txt → ../data/train/labels_converted\661.txt
# Converted 663.txt → ../data/train/labels_converted\663.txt
# Converted 665.txt → ../data/train/labels_converted\665.txt
# Converted 667.txt → ../data/train/labels_converted\667.txt
# Converted 668.txt → ../data/train/labels_converted\668.txt
# Converted 671.txt → ../data/train/labels_converted\671.txt
# Converted 672.txt → ../data/train/labels_converted\672.txt
# Converted 673.txt → ../data/train/labels_converted\673.txt
# Converted 674.txt → ../data/train/labels_converted\674.txt
# Converted 675.txt → ../data/train/labels_converted\675.txt
# Converted 676.txt → ../data/train/labels_converted\676.txt
# Converted 678.txt → ../data/train/labels_converted\678.txt
# Converted 679.txt → ../data/train/labels_converted\679.txt
# Converted 680.txt → ../data/train/labels_converted\680.txt
# Converted 683.txt → ../data/train/labels_converted\683.txt
# Converted 685.txt → ../data/train/labels_converted\685.txt
# Converted 686.txt → ../data/train/labels_converted\686.txt
# Converted 688.txt → ../data/train/labels_converted\688.txt
# Converted 690.txt → ../data/train/labels_converted\690.txt
# Converted 691.txt → ../data/train/labels_converted\691.txt
# Converted 692.txt → ../data/train/labels_converted\692.txt
# Converted 693.txt → ../data/train/labels_converted\693.txt
# Converted 694.txt → ../data/train/labels_converted\694.txt
# Converted 695.txt → ../data/train/labels_converted\695.txt
# Converted 696.txt → ../data/train/labels_converted\696.txt
# Converted 697.txt → ../data/train/labels_converted\697.txt
# Converted 698.txt → ../data/train/labels_converted\698.txt
# Converted 699.txt → ../data/train/labels_converted\699.txt
# Converted 700.txt → ../data/train/labels_converted\700.txt
# Converted 701.txt → ../data/train/labels_converted\701.txt
# Converted 702.txt → ../data/train/labels_converted\702.txt
# Converted 703.txt → ../data/train/labels_converted\703.txt
# Converted 704.txt → ../data/train/labels_converted\704.txt
# Converted 705.txt → ../data/train/labels_converted\705.txt
# Converted 706.txt → ../data/train/labels_converted\706.txt
# Converted 707.txt → ../data/train/labels_converted\707.txt
# Converted 708.txt → ../data/train/labels_converted\708.txt
# Converted 710.txt → ../data/train/labels_converted\710.txt
# Converted 711.txt → ../data/train/labels_converted\711.txt
# Converted 712.txt → ../data/train/labels_converted\712.txt
# Converted 713.txt → ../data/train/labels_converted\713.txt
# Converted 714.txt → ../data/train/labels_converted\714.txt
# Converted 715.txt → ../data/train/labels_converted\715.txt
# Converted 716.txt → ../data/train/labels_converted\716.txt
# Converted 717.txt → ../data/train/labels_converted\717.txt
# Converted 718.txt → ../data/train/labels_converted\718.txt
# Converted 719.txt → ../data/train/labels_converted\719.txt
# Converted 722.txt → ../data/train/labels_converted\722.txt
# Converted 723.txt → ../data/train/labels_converted\723.txt
# Converted 724.txt → ../data/train/labels_converted\724.txt
# Converted 726.txt → ../data/train/labels_converted\726.txt
# Converted 727.txt → ../data/train/labels_converted\727.txt
# Converted 728.txt → ../data/train/labels_converted\728.txt
# Converted 729.txt → ../data/train/labels_converted\729.txt
# Converted 731.txt → ../data/train/labels_converted\731.txt
# Converted 732.txt → ../data/train/labels_converted\732.txt
# Converted 734.txt → ../data/train/labels_converted\734.txt
# Converted 735.txt → ../data/train/labels_converted\735.txt
# Converted 737.txt → ../data/train/labels_converted\737.txt
# Converted 739.txt → ../data/train/labels_converted\739.txt
# Converted 741.txt → ../data/train/labels_converted\741.txt
# Converted 743.txt → ../data/train/labels_converted\743.txt
# Converted 744.txt → ../data/train/labels_converted\744.txt
# Converted 745.txt → ../data/train/labels_converted\745.txt
# Converted 748.txt → ../data/train/labels_converted\748.txt
# Converted 749.txt → ../data/train/labels_converted\749.txt
# Converted 750.txt → ../data/train/labels_converted\750.txt
# Converted 751.txt → ../data/train/labels_converted\751.txt
# Converted 753.txt → ../data/train/labels_converted\753.txt
# Converted 754.txt → ../data/train/labels_converted\754.txt
# Converted 755.txt → ../data/train/labels_converted\755.txt
# Converted 757.txt → ../data/train/labels_converted\757.txt
# Converted 759.txt → ../data/train/labels_converted\759.txt
# Converted 760.txt → ../data/train/labels_converted\760.txt
# Converted 761.txt → ../data/train/labels_converted\761.txt
# Converted 763.txt → ../data/train/labels_converted\763.txt
# Converted 764.txt → ../data/train/labels_converted\764.txt
# Converted 767.txt → ../data/train/labels_converted\767.txt
# Converted 768.txt → ../data/train/labels_converted\768.txt
# Converted 769.txt → ../data/train/labels_converted\769.txt
# Converted 770.txt → ../data/train/labels_converted\770.txt
# Converted 772.txt → ../data/train/labels_converted\772.txt
# Converted 773.txt → ../data/train/labels_converted\773.txt
# Converted 775.txt → ../data/train/labels_converted\775.txt
# Converted 776.txt → ../data/train/labels_converted\776.txt
# Converted 777.txt → ../data/train/labels_converted\777.txt
# Converted 778.txt → ../data/train/labels_converted\778.txt
# Converted 780.txt → ../data/train/labels_converted\780.txt
# Converted 781.txt → ../data/train/labels_converted\781.txt
# Converted 782.txt → ../data/train/labels_converted\782.txt
# Converted 783.txt → ../data/train/labels_converted\783.txt
# Converted 784.txt → ../data/train/labels_converted\784.txt
# Converted 785.txt → ../data/train/labels_converted\785.txt
# Converted 786.txt → ../data/train/labels_converted\786.txt
# Converted 787.txt → ../data/train/labels_converted\787.txt
# Converted 788.txt → ../data/train/labels_converted\788.txt
# Converted 790.txt → ../data/train/labels_converted\790.txt
# Converted 791.txt → ../data/train/labels_converted\791.txt
# Converted 792.txt → ../data/train/labels_converted\792.txt
# Converted 794.txt → ../data/train/labels_converted\794.txt
# Converted 795.txt → ../data/train/labels_converted\795.txt
# Converted 796.txt → ../data/train/labels_converted\796.txt
# Converted 797.txt → ../data/train/labels_converted\797.txt
# Converted 798.txt → ../data/train/labels_converted\798.txt
# Converted 800.txt → ../data/train/labels_converted\800.txt
# Converted 801.txt → ../data/train/labels_converted\801.txt
# Converted 803.txt → ../data/train/labels_converted\803.txt
# Converted 804.txt → ../data/train/labels_converted\804.txt
# Converted 805.txt → ../data/train/labels_converted\805.txt
# Converted 806.txt → ../data/train/labels_converted\806.txt
# Converted 808.txt → ../data/train/labels_converted\808.txt
# Converted 810.txt → ../data/train/labels_converted\810.txt
# Converted 812.txt → ../data/train/labels_converted\812.txt
# Converted 813.txt → ../data/train/labels_converted\813.txt
# Converted 815.txt → ../data/train/labels_converted\815.txt
# Converted 817.txt → ../data/train/labels_converted\817.txt
# Converted 818.txt → ../data/train/labels_converted\818.txt
# Converted 819.txt → ../data/train/labels_converted\819.txt
# Converted 820.txt → ../data/train/labels_converted\820.txt
# Converted 821.txt → ../data/train/labels_converted\821.txt
# Converted 822.txt → ../data/train/labels_converted\822.txt
# Converted 823.txt → ../data/train/labels_converted\823.txt
# Converted 824.txt → ../data/train/labels_converted\824.txt
# Converted 825.txt → ../data/train/labels_converted\825.txt
# Converted 826.txt → ../data/train/labels_converted\826.txt
# Converted 827.txt → ../data/train/labels_converted\827.txt
# Converted 828.txt → ../data/train/labels_converted\828.txt
# Converted 829.txt → ../data/train/labels_converted\829.txt
# Converted 832.txt → ../data/train/labels_converted\832.txt
# Converted 833.txt → ../data/train/labels_converted\833.txt
# Converted 834.txt → ../data/train/labels_converted\834.txt
# Converted 835.txt → ../data/train/labels_converted\835.txt
# Converted 836.txt → ../data/train/labels_converted\836.txt
# Converted 837.txt → ../data/train/labels_converted\837.txt
# Converted 838.txt → ../data/train/labels_converted\838.txt
# Converted 844.txt → ../data/train/labels_converted\844.txt
# Converted 845.txt → ../data/train/labels_converted\845.txt
# Converted 846.txt → ../data/train/labels_converted\846.txt
# Converted 847.txt → ../data/train/labels_converted\847.txt
# Converted 848.txt → ../data/train/labels_converted\848.txt
# Converted 849.txt → ../data/train/labels_converted\849.txt
# Converted 850.txt → ../data/train/labels_converted\850.txt
# Converted 851.txt → ../data/train/labels_converted\851.txt
# Converted 853.txt → ../data/train/labels_converted\853.txt
# Converted 856.txt → ../data/train/labels_converted\856.txt
# Converted 858.txt → ../data/train/labels_converted\858.txt
# Converted 859.txt → ../data/train/labels_converted\859.txt
# Converted 860.txt → ../data/train/labels_converted\860.txt
# Converted 861.txt → ../data/train/labels_converted\861.txt
# Converted 862.txt → ../data/train/labels_converted\862.txt
# Converted 863.txt → ../data/train/labels_converted\863.txt
# Converted 864.txt → ../data/train/labels_converted\864.txt
# Converted 865.txt → ../data/train/labels_converted\865.txt
# Converted 866.txt → ../data/train/labels_converted\866.txt
# Converted 867.txt → ../data/train/labels_converted\867.txt
# Converted 868.txt → ../data/train/labels_converted\868.txt
# Converted 869.txt → ../data/train/labels_converted\869.txt
# Converted 871.txt → ../data/train/labels_converted\871.txt
# Converted 872.txt → ../data/train/labels_converted\872.txt
# Converted 873.txt → ../data/train/labels_converted\873.txt
# Converted 876.txt → ../data/train/labels_converted\876.txt
# Converted 877.txt → ../data/train/labels_converted\877.txt
# Converted 879.txt → ../data/train/labels_converted\879.txt
# Converted 880.txt → ../data/train/labels_converted\880.txt
# Converted 881.txt → ../data/train/labels_converted\881.txt
# Converted 882.txt → ../data/train/labels_converted\882.txt
# Converted 883.txt → ../data/train/labels_converted\883.txt
# Converted 884.txt → ../data/train/labels_converted\884.txt
# Converted 885.txt → ../data/train/labels_converted\885.txt
# Converted 886.txt → ../data/train/labels_converted\886.txt
# Converted 887.txt → ../data/train/labels_converted\887.txt
# Converted 889.txt → ../data/train/labels_converted\889.txt
# Converted 891.txt → ../data/train/labels_converted\891.txt
# Converted 892.txt → ../data/train/labels_converted\892.txt
# Converted 894.txt → ../data/train/labels_converted\894.txt
# Converted 897.txt → ../data/train/labels_converted\897.txt
# Converted 898.txt → ../data/train/labels_converted\898.txt
# Converted 899.txt → ../data/train/labels_converted\899.txt
# Converted 900.txt → ../data/train/labels_converted\900.txt
# Converted 901.txt → ../data/train/labels_converted\901.txt
# Converted 902.txt → ../data/train/labels_converted\902.txt
# Converted 904.txt → ../data/train/labels_converted\904.txt
# Converted 905.txt → ../data/train/labels_converted\905.txt
# Converted 908.txt → ../data/train/labels_converted\908.txt
# Converted 910.txt → ../data/train/labels_converted\910.txt
# Converted 911.txt → ../data/train/labels_converted\911.txt
# Converted 912.txt → ../data/train/labels_converted\912.txt
# Converted 914.txt → ../data/train/labels_converted\914.txt
# Converted 915.txt → ../data/train/labels_converted\915.txt
# Converted 916.txt → ../data/train/labels_converted\916.txt
# Converted 917.txt → ../data/train/labels_converted\917.txt
# Converted 918.txt → ../data/train/labels_converted\918.txt
# Converted 920.txt → ../data/train/labels_converted\920.txt
# Converted 922.txt → ../data/train/labels_converted\922.txt
# Converted 923.txt → ../data/train/labels_converted\923.txt
# Converted 925.txt → ../data/train/labels_converted\925.txt
# Converted 926.txt → ../data/train/labels_converted\926.txt
# Converted 927.txt → ../data/train/labels_converted\927.txt
# Converted 928.txt → ../data/train/labels_converted\928.txt
# Converted 929.txt → ../data/train/labels_converted\929.txt
# Converted 930.txt → ../data/train/labels_converted\930.txt
# Converted 932.txt → ../data/train/labels_converted\932.txt
# Converted 933.txt → ../data/train/labels_converted\933.txt
# Converted 934.txt → ../data/train/labels_converted\934.txt
# Converted 935.txt → ../data/train/labels_converted\935.txt
# Converted 936.txt → ../data/train/labels_converted\936.txt
# Converted 937.txt → ../data/train/labels_converted\937.txt
# Converted 938.txt → ../data/train/labels_converted\938.txt
# Converted 939.txt → ../data/train/labels_converted\939.txt
# Converted 942.txt → ../data/train/labels_converted\942.txt
# Converted 943.txt → ../data/train/labels_converted\943.txt
# Converted 944.txt → ../data/train/labels_converted\944.txt
# Converted 946.txt → ../data/train/labels_converted\946.txt
# Converted 947.txt → ../data/train/labels_converted\947.txt
# Converted 948.txt → ../data/train/labels_converted\948.txt
# Converted 949.txt → ../data/train/labels_converted\949.txt
# Converted 950.txt → ../data/train/labels_converted\950.txt
# Converted 951.txt → ../data/train/labels_converted\951.txt
# Converted 952.txt → ../data/train/labels_converted\952.txt
# Converted 953.txt → ../data/train/labels_converted\953.txt
# Converted 955.txt → ../data/train/labels_converted\955.txt
# Converted 956.txt → ../data/train/labels_converted\956.txt
# Converted 958.txt → ../data/train/labels_converted\958.txt
# Converted 959.txt → ../data/train/labels_converted\959.txt
# Converted 960.txt → ../data/train/labels_converted\960.txt
# Converted 962.txt → ../data/train/labels_converted\962.txt
# Converted 963.txt → ../data/train/labels_converted\963.txt
# Converted 964.txt → ../data/train/labels_converted\964.txt
# Converted 965.txt → ../data/train/labels_converted\965.txt
# Converted 966.txt → ../data/train/labels_converted\966.txt
# Converted 968.txt → ../data/train/labels_converted\968.txt
# Converted 969.txt → ../data/train/labels_converted\969.txt
# Converted 970.txt → ../data/train/labels_converted\970.txt
# Converted 972.txt → ../data/train/labels_converted\972.txt
# Converted 973.txt → ../data/train/labels_converted\973.txt
# Converted 974.txt → ../data/train/labels_converted\974.txt
# Converted 975.txt → ../data/train/labels_converted\975.txt
# Converted 976.txt → ../data/train/labels_converted\976.txt
# Converted 979.txt → ../data/train/labels_converted\979.txt
# Converted 981.txt → ../data/train/labels_converted\981.txt
# Converted 982.txt → ../data/train/labels_converted\982.txt
# Converted 983.txt → ../data/train/labels_converted\983.txt
# Converted 985.txt → ../data/train/labels_converted\985.txt
# Converted 987.txt → ../data/train/labels_converted\987.txt
# Converted 988.txt → ../data/train/labels_converted\988.txt
# Converted 989.txt → ../data/train/labels_converted\989.txt
# Converted 991.txt → ../data/train/labels_converted\991.txt
# Converted 992.txt → ../data/train/labels_converted\992.txt
# Converted 994.txt → ../data/train/labels_converted\994.txt
# Converted 995.txt → ../data/train/labels_converted\995.txt
# Converted 996.txt → ../data/train/labels_converted\996.txt
# Converted 997.txt → ../data/train/labels_converted\997.txt
# Converted 999.txt → ../data/train/labels_converted\999.txt
# Converted 1010.txt → ../data/val/labels_converted\1010.txt
# Converted 1013.txt → ../data/val/labels_converted\1013.txt
# Converted 1018.txt → ../data/val/labels_converted\1018.txt
# Converted 1019.txt → ../data/val/labels_converted\1019.txt
# Converted 1026.txt → ../data/val/labels_converted\1026.txt
# Converted 1028.txt → ../data/val/labels_converted\1028.txt
# Converted 1040.txt → ../data/val/labels_converted\1040.txt
# Converted 1043.txt → ../data/val/labels_converted\1043.txt
# Converted 1048.txt → ../data/val/labels_converted\1048.txt
# Converted 1051.txt → ../data/val/labels_converted\1051.txt
# Converted 1062.txt → ../data/val/labels_converted\1062.txt
# Converted 1072.txt → ../data/val/labels_converted\1072.txt
# Converted 1076.txt → ../data/val/labels_converted\1076.txt
# Converted 1081.txt → ../data/val/labels_converted\1081.txt
# Converted 1087.txt → ../data/val/labels_converted\1087.txt
# Converted 1092.txt → ../data/val/labels_converted\1092.txt
# Converted 1101.txt → ../data/val/labels_converted\1101.txt
# Converted 1102.txt → ../data/val/labels_converted\1102.txt
# Converted 1106.txt → ../data/val/labels_converted\1106.txt
# Converted 1120.txt → ../data/val/labels_converted\1120.txt
# Converted 1132.txt → ../data/val/labels_converted\1132.txt
# Converted 1134.txt → ../data/val/labels_converted\1134.txt
# Converted 1137.txt → ../data/val/labels_converted\1137.txt
# Converted 1146.txt → ../data/val/labels_converted\1146.txt
# Converted 1153.txt → ../data/val/labels_converted\1153.txt
# Converted 1170.txt → ../data/val/labels_converted\1170.txt
# Converted 1176.txt → ../data/val/labels_converted\1176.txt
# Converted 1179.txt → ../data/val/labels_converted\1179.txt
# Converted 1181.txt → ../data/val/labels_converted\1181.txt
# Converted 1196.txt → ../data/val/labels_converted\1196.txt
# Converted 1199.txt → ../data/val/labels_converted\1199.txt
# Converted 1202.txt → ../data/val/labels_converted\1202.txt
# Converted 1204.txt → ../data/val/labels_converted\1204.txt
# Converted 1223.txt → ../data/val/labels_converted\1223.txt
# Converted 1227.txt → ../data/val/labels_converted\1227.txt
# Converted 1232.txt → ../data/val/labels_converted\1232.txt
# Converted 1234.txt → ../data/val/labels_converted\1234.txt
# Converted 1237.txt → ../data/val/labels_converted\1237.txt
# Converted 1238.txt → ../data/val/labels_converted\1238.txt
# Converted 1243.txt → ../data/val/labels_converted\1243.txt
# Converted 1252.txt → ../data/val/labels_converted\1252.txt
# Converted 1254.txt → ../data/val/labels_converted\1254.txt
# Converted 1268.txt → ../data/val/labels_converted\1268.txt
# Converted 1270.txt → ../data/val/labels_converted\1270.txt
# Converted 1281.txt → ../data/val/labels_converted\1281.txt
# Converted 1293.txt → ../data/val/labels_converted\1293.txt
# Converted 1294.txt → ../data/val/labels_converted\1294.txt
# Converted 1302.txt → ../data/val/labels_converted\1302.txt
# Converted 1305.txt → ../data/val/labels_converted\1305.txt
# Converted 1312.txt → ../data/val/labels_converted\1312.txt
# Converted 1317.txt → ../data/val/labels_converted\1317.txt
# Converted 1326.txt → ../data/val/labels_converted\1326.txt
# Converted 1336.txt → ../data/val/labels_converted\1336.txt
# Converted 1342.txt → ../data/val/labels_converted\1342.txt
# Converted 1355.txt → ../data/val/labels_converted\1355.txt
# Converted 1356.txt → ../data/val/labels_converted\1356.txt
# Converted 1364.txt → ../data/val/labels_converted\1364.txt
# Converted 407.txt → ../data/val/labels_converted\407.txt
# Converted 411.txt → ../data/val/labels_converted\411.txt
# Converted 417.txt → ../data/val/labels_converted\417.txt
# Converted 418.txt → ../data/val/labels_converted\418.txt
# Converted 421.txt → ../data/val/labels_converted\421.txt
# Converted 431.txt → ../data/val/labels_converted\431.txt
# Converted 434.txt → ../data/val/labels_converted\434.txt
# Converted 452.txt → ../data/val/labels_converted\452.txt
# Converted 462.txt → ../data/val/labels_converted\462.txt
# Converted 473.txt → ../data/val/labels_converted\473.txt
# Converted 476.txt → ../data/val/labels_converted\476.txt
# Converted 478.txt → ../data/val/labels_converted\478.txt
# Converted 484.txt → ../data/val/labels_converted\484.txt
# Converted 489.txt → ../data/val/labels_converted\489.txt
# Converted 500.txt → ../data/val/labels_converted\500.txt
# Converted 504.txt → ../data/val/labels_converted\504.txt
# Converted 505.txt → ../data/val/labels_converted\505.txt
# Converted 506.txt → ../data/val/labels_converted\506.txt
# Converted 511.txt → ../data/val/labels_converted\511.txt
# Converted 515.txt → ../data/val/labels_converted\515.txt
# Converted 516.txt → ../data/val/labels_converted\516.txt
# Converted 517.txt → ../data/val/labels_converted\517.txt
# Converted 559.txt → ../data/val/labels_converted\559.txt
# Converted 560.txt → ../data/val/labels_converted\560.txt
# Converted 568.txt → ../data/val/labels_converted\568.txt
# Converted 582.txt → ../data/val/labels_converted\582.txt
# Converted 591.txt → ../data/val/labels_converted\591.txt
# Converted 592.txt → ../data/val/labels_converted\592.txt
# Converted 595.txt → ../data/val/labels_converted\595.txt
# Converted 598.txt → ../data/val/labels_converted\598.txt
# Converted 605.txt → ../data/val/labels_converted\605.txt
# Converted 630.txt → ../data/val/labels_converted\630.txt
# Converted 638.txt → ../data/val/labels_converted\638.txt
# Converted 641.txt → ../data/val/labels_converted\641.txt
# Converted 652.txt → ../data/val/labels_converted\652.txt
# Converted 662.txt → ../data/val/labels_converted\662.txt
# Converted 664.txt → ../data/val/labels_converted\664.txt
# Converted 666.txt → ../data/val/labels_converted\666.txt
# Converted 670.txt → ../data/val/labels_converted\670.txt
# Converted 677.txt → ../data/val/labels_converted\677.txt
# Converted 682.txt → ../data/val/labels_converted\682.txt
# Converted 721.txt → ../data/val/labels_converted\721.txt
# Converted 725.txt → ../data/val/labels_converted\725.txt
# Converted 733.txt → ../data/val/labels_converted\733.txt
# Converted 736.txt → ../data/val/labels_converted\736.txt
# Converted 738.txt → ../data/val/labels_converted\738.txt
# Converted 740.txt → ../data/val/labels_converted\740.txt
# Converted 742.txt → ../data/val/labels_converted\742.txt
# Converted 746.txt → ../data/val/labels_converted\746.txt
# Converted 747.txt → ../data/val/labels_converted\747.txt
# Converted 752.txt → ../data/val/labels_converted\752.txt
# Converted 756.txt → ../data/val/labels_converted\756.txt
# Converted 762.txt → ../data/val/labels_converted\762.txt
# Converted 765.txt → ../data/val/labels_converted\765.txt
# Converted 766.txt → ../data/val/labels_converted\766.txt
# Converted 779.txt → ../data/val/labels_converted\779.txt
# Converted 789.txt → ../data/val/labels_converted\789.txt
# Converted 793.txt → ../data/val/labels_converted\793.txt
# Converted 799.txt → ../data/val/labels_converted\799.txt
# Converted 809.txt → ../data/val/labels_converted\809.txt
# Converted 814.txt → ../data/val/labels_converted\814.txt
# Converted 816.txt → ../data/val/labels_converted\816.txt
# Converted 830.txt → ../data/val/labels_converted\830.txt
# Converted 831.txt → ../data/val/labels_converted\831.txt
# Converted 839.txt → ../data/val/labels_converted\839.txt
# Converted 841.txt → ../data/val/labels_converted\841.txt
# Converted 854.txt → ../data/val/labels_converted\854.txt
# Converted 855.txt → ../data/val/labels_converted\855.txt
# Converted 857.txt → ../data/val/labels_converted\857.txt
# Converted 875.txt → ../data/val/labels_converted\875.txt
# Converted 888.txt → ../data/val/labels_converted\888.txt
# Converted 893.txt → ../data/val/labels_converted\893.txt
# Converted 895.txt → ../data/val/labels_converted\895.txt
# Converted 906.txt → ../data/val/labels_converted\906.txt
# Converted 907.txt → ../data/val/labels_converted\907.txt
# Converted 913.txt → ../data/val/labels_converted\913.txt
# Converted 919.txt → ../data/val/labels_converted\919.txt
# Converted 924.txt → ../data/val/labels_converted\924.txt
# Converted 940.txt → ../data/val/labels_converted\940.txt
# Converted 945.txt → ../data/val/labels_converted\945.txt
# Converted 954.txt → ../data/val/labels_converted\954.txt
# Converted 957.txt → ../data/val/labels_converted\957.txt
# Converted 971.txt → ../data/val/labels_converted\971.txt
# Converted 978.txt → ../data/val/labels_converted\978.txt
# Converted 980.txt → ../data/val/labels_converted\980.txt
# Converted 990.txt → ../data/val/labels_converted\990.txt
# Converted 998.txt → ../data/val/labels_converted\998.txt
